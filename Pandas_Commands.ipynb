# %% [markdown]
# <a href="https://colab.research.google.com/github/cagBRT/Intro-to-Pandas/blob/master/Pandas_Commands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns

# %%
city_list = ["New York", "Manchester", "California", "Munich", "Bombay",
             "Sydeny", "London", "Moscow", "Dubai", "Tokyo"]

job_list = ["Software Development Engineer", "Research Engineer",
            "Test Engineer", "Software Development Engineer-II",
            "Python Developer", "Back End Developer",
            "Front End Developer", "Data Scientist",
            "IOS Developer", "Android Developer"]

cmp_list = ["Amazon", "Google", "Infosys", "Mastercard", "Microsoft",
            "Uber", "IBM", "Apple", "Wipro", "Cognizant"]

# %%
data = []
for i in range(1000):
    company = random.choice(cmp_list)
    job = random.choice(job_list)
    city = random.choice(city_list)
    salary = int(round(np.random.rand(), 3)*10**6)
    employment = random.choices(["Full Time", "Intern"], weights=(80, 20))[0]
    rating = round((np.random.rand()*5), 1)

    data.append([company, job, city, salary, employment, rating])

data = pd.DataFrame(data, columns=["Company Name", "Employee Job Title",
                                   "Employee Work Location",  "Employee Salary",
                                   "Employment Status", "Employee Rating"])

# %%
data
# Out:
#     Company Name                Employee Job Title Employee Work Location  \
# 0     Mastercard                    Data Scientist             Manchester
# 1          Apple                Back End Developer                 Sydeny
# 2      Cognizant                 Research Engineer                 Munich
# 3           Uber               Front End Developer             Manchester
# 4         Amazon                     IOS Developer                 Sydeny
# ..           ...                               ...                    ...
# 995        Apple  Software Development Engineer-II                  Tokyo
# 996    Cognizant                     Test Engineer             Manchester
# 997        Apple                 Research Engineer               New York
# 998      Infosys  Software Development Engineer-II                 Moscow
# 999    Microsoft     Software Development Engineer             Manchester
#
#      Employee Salary Employment Status  Employee Rating
# 0             159000            Intern              5.0
# 1             871000         Full Time              2.7
# 2             804000         Full Time              1.3
# 3              82000         Full Time              4.1
# 4             488000         Full Time              3.6
# ..               ...               ...              ...
# 995           826000            Intern              3.5
# 996           817000         Full Time              4.9
# 997           678000            Intern              1.3
# 998           693000         Full Time              0.9
# 999           911000         Full Time              0.2
#
# [1000 rows x 6 columns]

# %% [markdown]
# **n-largest values in a series**

# %% [markdown]
# **keep**
# When duplicate values exist, we need to specify which particular row(s) we want in the final output. This is done using the keep argument that can take the following values:

# %% [markdown]
# keep = "first": prioritizes the first occurrence.<br>
# keep = "last": prioritizes the last occurrence.<br>
# keep = "all": Does not drop any duplicates, even if it means selecting more than n items (like in the image above).<br>

# %%
n = 6
data.nlargest(n, "Employee Salary", keep = "all")
# Out:
#     Company Name   Employee Job Title Employee Work Location  Employee Salary  \
# 151    Cognizant  Front End Developer                 Bombay           998000
# 455    Microsoft     Python Developer               New York           995000
# 296   Mastercard    Research Engineer             California           990000
# 531        Apple   Back End Developer                  Dubai           990000
# 990   Mastercard   Back End Developer             Manchester           990000
# 844          IBM     Python Developer                 Munich           989000
#
#     Employment Status  Employee Rating
# 151         Full Time              0.3
# 455         Full Time              1.4
# 296         Full Time              1.3
# 531         Full Time              2.7
# 990         Full Time              3.8
# 844         Full Time              3.0

# %% [markdown]
# **sort_values**

# %%
n=6
data.sort_values("Employee Salary", ascending=False).head(n)
# Out:
#     Company Name   Employee Job Title Employee Work Location  Employee Salary  \
# 151    Cognizant  Front End Developer                 Bombay           998000
# 455    Microsoft     Python Developer               New York           995000
# 531        Apple   Back End Developer                  Dubai           990000
# 990   Mastercard   Back End Developer             Manchester           990000
# 296   Mastercard    Research Engineer             California           990000
# 844          IBM     Python Developer                 Munich           989000
#
#     Employment Status  Employee Rating
# 151         Full Time              0.3
# 455         Full Time              1.4
# 531         Full Time              2.7
# 990         Full Time              3.8
# 296         Full Time              1.3
# 844         Full Time              3.0

# %% [markdown]
#  **n-smallest values in a series**<br>
#
# This method returns the first n rows with the smallest values in column(s), arranged in ascending order. The arguments passed here are the same as those specified in the nlargest() method.

# %%
n = 7
data.nsmallest(n, "Employee Salary", keep = "all")
# Out:
#     Company Name                Employee Job Title Employee Work Location  \
# 165   Mastercard                Back End Developer             Manchester
# 451         Uber                     Test Engineer             Manchester
# 864    Cognizant  Software Development Engineer-II                  Tokyo
# 788         Uber                Back End Developer                 London
# 840        Apple                  Python Developer             California
# 155   Mastercard                  Python Developer                  Dubai
# 459          IBM               Front End Developer                 Bombay
#
#      Employee Salary Employment Status  Employee Rating
# 165             2000         Full Time              0.6
# 451             3000         Full Time              2.4
# 864             4000         Full Time              1.5
# 788             6000         Full Time              2.8
# 840             6000         Full Time              1.2
# 155             8000         Full Time              5.0
# 459             8000         Full Time              2.4

# %% [markdown]
# **CrossTabs**<br>
# Crosstab allows you to compute a cross-tabulation of two (or more) columns/series and returns a frequency of each combination by default. In other words, crosstab() takes one column/list, displays its unique values as indexes, and then takes another column/list and displays its unique values as the column headers. The values in the individual cells are computed using an aggregation function. By default, they indicate the co-occurrence frequency.

# %%
data
# Out:
#     Company Name                Employee Job Title Employee Work Location  \
# 0     Mastercard                    Data Scientist             Manchester
# 1          Apple                Back End Developer                 Sydeny
# 2      Cognizant                 Research Engineer                 Munich
# 3           Uber               Front End Developer             Manchester
# 4         Amazon                     IOS Developer                 Sydeny
# ..           ...                               ...                    ...
# 995        Apple  Software Development Engineer-II                  Tokyo
# 996    Cognizant                     Test Engineer             Manchester
# 997        Apple                 Research Engineer               New York
# 998      Infosys  Software Development Engineer-II                 Moscow
# 999    Microsoft     Software Development Engineer             Manchester
#
#      Employee Salary Employment Status  Employee Rating
# 0             159000            Intern              5.0
# 1             871000         Full Time              2.7
# 2             804000         Full Time              1.3
# 3              82000         Full Time              4.1
# 4             488000         Full Time              3.6
# ..               ...               ...              ...
# 995           826000            Intern              3.5
# 996           817000         Full Time              4.9
# 997           678000            Intern              1.3
# 998           693000         Full Time              0.9
# 999           911000         Full Time              0.2
#
# [1000 rows x 6 columns]

# %%
pd.crosstab(data["Company Name"], data["Employee Work Location"])
# Out:
# Employee Work Location  Bombay  California  Dubai  London  Manchester  Moscow  \
# Company Name
# Amazon                      10          11     14       4          14      11
# Apple                       10           9     15       6           8      13
# Cognizant                   14           9     12      12          13       4
# Google                      12           6      9      12           7       5
# IBM                          9          11     10      12           6      15
# Infosys                     11          10      7       6          13       7
# Mastercard                   4           9     10      22          12       5
# Microsoft                   15          13     10      13           7      12
# Uber                        10          15     12      10          10      15
# Wipro                       12           8     10       7          11       9
#
# Employee Work Location  Munich  New York  Sydeny  Tokyo
# Company Name
# Amazon                      11        10       8     12
# Apple                        9        17      15     10
# Cognizant                    7         5      10      8
# Google                       7        14      14      5
# IBM                         10        14      11      8
# Infosys                      9         8       8      8
# Mastercard                   9         8       5     12
# Microsoft                   11        15       5     10
# Uber                         5        14       9      7
# Wipro                        6         8       9     11

# %% [markdown]
# **Visual cross_Tab**

# %%
result_crosstab = pd.crosstab(data["Company Name"], data["Employee Work Location"])
sns.heatmap(result_crosstab, annot=True)
# Out:
# <Axes: xlabel='Employee Work Location', ylabel='Company Name'>

# %% [markdown]
# **Pivot Table**<br>
#  pivot_table() method to find the frequency of co-occurrence between the “Company Name” and “Location”:

# %%
pd.pivot_table(data,
               index=["Company Name"],
               columns=["Employee Work Location"],
               aggfunc='size',
               fill_value=0)
# Out:
# Employee Work Location  Bombay  California  Dubai  London  Manchester  Moscow  \
# Company Name
# Amazon                      10          11     14       4          14      11
# Apple                       10           9     15       6           8      13
# Cognizant                   14           9     12      12          13       4
# Google                      12           6      9      12           7       5
# IBM                          9          11     10      12           6      15
# Infosys                     11          10      7       6          13       7
# Mastercard                   4           9     10      22          12       5
# Microsoft                   15          13     10      13           7      12
# Uber                        10          15     12      10          10      15
# Wipro                       12           8     10       7          11       9
#
# Employee Work Location  Munich  New York  Sydeny  Tokyo
# Company Name
# Amazon                      11        10       8     12
# Apple                        9        17      15     10
# Cognizant                    7         5      10      8
# Google                       7        14      14      5
# IBM                         10        14      11      8
# Infosys                      9         8       8      8
# Mastercard                   9         8       5     12
# Microsoft                   11        15       5     10
# Uber                         5        14       9      7
# Wipro                        6         8       9     11

# %% [markdown]
# **Visual pivot_table**

# %%
result_pivot = pd.pivot_table(data,
                              index=["Company Name"],
                              columns=["Employee Work Location"],
                              aggfunc='size',
                              fill_value=0)

sns.heatmap(result_pivot, annot = True, fmt = 'g')
# Out:
# <Axes: xlabel='Employee Work Location', ylabel='Company Name'>

# %% [markdown]
# **Handling Duplicated Data**<br>

# %%
data.duplicated(keep = "first")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data.drop_duplicates(keep = "first")
# Out:
#     Company Name                Employee Job Title Employee Work Location  \
# 0     Mastercard                    Data Scientist             Manchester
# 1          Apple                Back End Developer                 Sydeny
# 2      Cognizant                 Research Engineer                 Munich
# 3           Uber               Front End Developer             Manchester
# 4         Amazon                     IOS Developer                 Sydeny
# ..           ...                               ...                    ...
# 995        Apple  Software Development Engineer-II                  Tokyo
# 996    Cognizant                     Test Engineer             Manchester
# 997        Apple                 Research Engineer               New York
# 998      Infosys  Software Development Engineer-II                 Moscow
# 999    Microsoft     Software Development Engineer             Manchester
#
#      Employee Salary Employment Status  Employee Rating
# 0             159000            Intern              5.0
# 1             871000         Full Time              2.7
# 2             804000         Full Time              1.3
# 3              82000         Full Time              4.1
# 4             488000         Full Time              3.6
# ..               ...               ...              ...
# 995           826000            Intern              3.5
# 996           817000         Full Time              4.9
# 997           678000            Intern              1.3
# 998           693000         Full Time              0.9
# 999           911000         Full Time              0.2
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Using apply

# %%
df = pd.DataFrame([
    ['apple', 4],
    ['orange', 5],
    ['pear', 6]
], columns=['fruit', 'price'])

df
# Out:
#     fruit  price
# 0   apple      4
# 1  orange      5
# 2    pear      6

# %% [markdown]
# To square all the values in a column

# %%
df['price'] = df['price'].apply(lambda x:x**2)
df
# Out:
#     fruit  price
# 0   apple     16
# 1  orange     25
# 2    pear     36

# %% [markdown]
# **Create a new column**<br>
#
# Create a new column price_squared — where values are the squares of the values in price

# %%
df['price_squared'] = df['price'] ** 2
df
# Out:
#     fruit  price  price_squared
# 0   apple     16            256
# 1  orange     25            625
# 2    pear     36           1296

# %% [markdown]
# **To rename a column**

# %%
df = df.rename(columns={'fruit':'plant_flesh', 'price':'monetary_value'})
df
# Out:
#   plant_flesh  monetary_value  price_squared
# 0       apple              16            256
# 1      orange              25            625
# 2        pear              36           1296

# %% [markdown]
# **Filtering values in DataFrames**

# %%
df[df['monetary_value']>= 5]
# Out:
#   plant_flesh  monetary_value  price_squared
# 0       apple              16            256
# 1      orange              25            625
# 2        pear              36           1296

# %% [markdown]
# Filtering Nan values and using "~"

# %%
df = pd.DataFrame([
    ['apple', 4],
    ['orange', None],
    ['pear', 6],
    ['durian', None],
], columns=['fruit', 'price'])

df
# Out:
#     fruit  price
# 0   apple    4.0
# 1  orange    NaN
# 2    pear    6.0
# 3  durian    NaN

# %%
df[df['price'].isna()]
# Out:
#     fruit  price
# 1  orange    NaN
# 3  durian    NaN

# %% [markdown]
# **Use "~" invert the command**

# %%
df[~df['price'].isna()]
# Out:
#    fruit  price
# 0  apple    4.0
# 2   pear    6.0
